# %% [markdown]
# # Google drive mount
# #### * google colab 사용 시, google drive 내 데이터를 사용하기 위한 절차입니다

# %%
# google drive에 있는 데이터를 사용하기 위해 접근

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # GPU Test
# #### * 현재 코랩에서 GPU 사용이 가능한지 테스트하는 절차입니다

# %%
# tensorflow를 import 하고, 현재 colab에서 gpu 구동이 되고 있는지 테스트 하는 코드
# Found GPU at: /device:GPU ~ 가 뜨면 성공

import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # library import
# #### 모듈 사용을 위해 import 하는 절차입니다

# %%
# konlpy, Mecab 형태소 분석기 설치 스크립트 실행
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# 필요 library import
import pandas as pd
import numpy as np
import seaborn as sns
import re
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_curve, roc_auc_score
from konlpy.tag import Mecab
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Input, Embedding, LSTM, Bidirectional, Dense, Dropout, concatenate, BatchNormalization, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # Data load
# #### * Model 학습에 사용할 데이터를 불러오는 절차입니다

# %%
# data 경로(데이터가 있는 경로에 맞게 바꿔주셔야 합니다.)
data_path = './drive/MyDrive/숨고/전광호님(가짜 뉴스 분류)/' 

# data load
data = pd.read_csv(data_path + "Mission2_sample_1차수정본.csv")

data.head()
# Out:
#        식별자                                       뉴스제목  \
# 0  2_00001            세월호 유가족 위해 '물놀이' 프로그램 기획한 센터 논란
# 1  2_00002  "너무 미안해, 사랑해..." 아프리카에서 숨진 PD에게 부인이 보낸 편지
# 2  2_00003                   폐교 수순 서남대' 재조명된 캠퍼스 투어 글
# 3  2_00004          빠른 회복' 김병만, 비행기 타고 오늘(2일) 전격 귀국한다
# 4  2_00005                           강호동 분노케한 이수근 드립
#
#                                                 뉴스본문  Label
# 0  세월호 유가족이 받은 치유센터 문자가 논란이 됐다.\n\n지난달 31일 세월호 유가...      1
# 1  남아프리카공화국에서 다큐멘터리 촬영을 하다 교통사고로 사망한 고 김광일 EBS PD...      1
# 2  재정 위기로 폐교 수순을 밟을 것으로 보이는 전북 서남대 '캠퍼스 투어' 글이 재조...      1
# 3  미국에서 스카이다이빙 도중 척추 뼈 부상을 당한 김병만 씨가 오늘(2일) 전격 귀국...      1
# 4  신서유기4' 이수근(42) 씨가 강호동(47) 씨 국밥 상황극에 찬물을 끼얹었다. ...      1

# %% [markdown]
# # EDA
# #### * 주어진 데이터로 간단한 분석을 실시합니다

# %%
# 데이터 내 진짜(0), 가짜(1) 의 각 비율 확인
sns.countplot(data = data, x='Label')

# %%
# 가짜 뉴스의 내용과 진짜 뉴스의 겹치는 내용 수
real_news_content = set(data[data['Label'] == 1]['뉴스본문'].unique()) 
fake_news_content = set(data[data['Label'] == 0]['뉴스본문'].unique())
print("내용이 겹치는 기사 수 :", len(real_news_content & fake_news_content))
print("내용이 겹치는 비율 :", len(real_news_content & fake_news_content)/data['뉴스본문'].nunique())
# Out:
# 내용이 겹치는 기사 수 : 0
# 내용이 겹치는 비율 : 0.0

# %%
# 내용 길이에 대한 분석
data['content_len'] = data['뉴스본문'].apply(lambda x : len(x))

plt.figure(figsize=(10,5))
sns.boxplot(data = data, y='content_len', x='Label')
plt.show()

plt.figure(figsize=(10,5))
sns.distplot(data[data['Label'] == 1]['content_len'], color='red', label='1')
sns.distplot(data[data['Label'] == 0]['content_len'], color='blue', label='0')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # NLP 진행
# #### mecab을 이용한 전처리 및 형태소 분석

# %%
# stopword 불러오기
f = open(data_path + "koreanStopwords.txt", 'r')
lines = f.readlines()
stopwords = []
for line in lines:
    line = line.replace('\n', '')
    stopwords.append(line)
f.close()

stopwords = stopwords+['간','갑','갤','걸','게','겠','고','과','구','꺼','꺾','꼽','끌','끼','낳','넘','놓','뉴','는','늘',
           '니','다','대','던','도','돼','됐','된','됨','듯','딩','딱','딸','뜨','라','러','렉','렌','로','록','론','롭',
           '를','마','막','만','맑','맞','맨','맷','먹','먼','며','면','무','문','미','및','바','박','백','본','새','생','쉽',
           '시','식','신','실','써','썼','쏘','쓰','쓴','씩','아','악','았','애','앱','약','양','어','억','었','에','엔','여',
           '열','올','와','유','율','은','을','음','의','자','작','잔','재','잭','저','전','정','제','젤','조','족',
           '준','줄','질','짓','째','쯔','쯤','찌','첨','초','출','취','측','치','쿡','퀘','탈','탑','테','통','트','튼',
           '판','팟','팬','평','폰','표','할','해','했','혼','화','후']

# %%
# stopword 처리 및 형태소 추출 
mecab = Mecab()

def preprocessing(text_list):
    korean = re.compile('[^ ㄱ-ㅣ가-힣]+')

    preprocessed_text = []
    for text in text_list:
        text = korean.sub('', str(text))
        tokens = mecab.morphs(text)
        tokens = [token for token in tokens if token not in stopwords]
        preprocessed_text.append(tokens)

    return preprocessed_text

data['processed_title'] = preprocessing(data['뉴스제목'])
data['processed_content'] = preprocessing(data['뉴스본문'])

# %%
def text_to_sequence(text, max_len=1000):
    
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(text)
    text_sequence = tokenizer.texts_to_sequences(text)
    vocab_size = len(tokenizer.word_index) + 1
    print('vocab_size : ', vocab_size)
    text_sequence = pad_sequences(text_sequence, maxlen = max_len)
    return text_sequence, vocab_size

y_data = data['Label']
x_data_title, title_vocab_size = text_to_sequence(data['processed_title'], max_len = 50)
x_data_content, content_vocab_size = text_to_sequence(data['processed_content'], max_len = 1000)
print(x_data_title.shape, x_data_content.shape)
# Out:
# vocab_size :  1802
# vocab_size :  12324
# (350, 50) (350, 1000)

# %%
# train/test split
x_train_title,x_test_title,x_train_content,x_test_content,y_train,y_test = train_test_split(x_data_title, x_data_content,y_data, test_size = 0.2, random_state=20220830, stratify=y_data)

# %% [markdown]
# # Training Model
# #### * 모델 학습을 위한 과정입니다.(모델은 LSTM 모델을 사용하였습니다)

# %%
## lstm layer 생성
title_timestep = 50
title_column = title_vocab_size
content_timestep = 50
content_column = content_vocab_size
learning_rate = 0.0001
batch_size = 16
epochs = 300

def model(emb_input, timesteps, max_words):
	# lstm model
    emb_model = Embedding(max_words, 50, input_length=timesteps)(emb_input)
    # lstm_out = Bidirectional(LSTM(128, dropout=0.3, recurrent_dropout=0.3, return_sequences=True))(emb_model)
    # lstm_out = Bidirectional(LSTM(64, dropout=0.3, recurrent_dropout=0.3))(emb_model)
    lstm_out = Bidirectional(LSTM(64, dropout=0.3, recurrent_dropout=0.3))(emb_model)

    return lstm_out

# content process
content_input = Input(shape=(None,))
content_model = model(content_input, content_timestep, content_column)
content_model = Flatten()(content_model)
content_model = Dense(64, activation='relu',kernel_initializer='he_normal')(content_model)
content_model = BatchNormalization()(content_model)
content_model = Dense(32, activation='relu',kernel_initializer='he_normal')(content_model)
content_model = BatchNormalization()(content_model)
model_out = Dense(1, activation='sigmoid')(content_model)

concat_model = Model([content_input], model_out)

optimizer = optimizers.Adam(learning_rate=learning_rate) # optimizer 지정 

# model의 loss function, 사용할 optimizer, metirc 정의
concat_model.compile(loss='binary_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy']) 

concat_model.summary() # 모델 전체 아키텍처 출력
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 50)          616200
#
#  bidirectional (Bidirectiona  (None, 128)              58880
#  l)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 685,833
# Trainable params: 685,641
# Non-trainable params: 192
# _________________________________________________________________

# %%
best_weights_file="./drive/MyDrive/숨고/전광호님(가짜 뉴스 분류)/weights_mission2.best.hdf5"
checkpoint = ModelCheckpoint(best_weights_file, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max') # 학습 중 validation acc 기준 최상의 모델을 저장하도록 checkpoint 설정
es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=15)

# model 학습 설정 및 학습 진행(주입할 input, label 데이터/batch_size/epochs/모델 저장/학습과정출력여부/학습 중 val_loss를 계산할 데이터비율, epoch마다 셔플 여부)
history = concat_model.fit([x_train_content], y_train,
        batch_size=batch_size,
        epochs=epochs,
        callbacks=[checkpoint, es] ,
        verbose=1,
        validation_split=0.1,
        shuffle=True)
# Out:
# Epoch 1/300
# 16/16 [==============================] - ETA: 0s - loss: 0.8058 - accuracy: 0.5198
# Epoch 1: val_accuracy improved from -inf to 0.64286, saving model to ./drive/MyDrive/숨고/전광호님(가짜 뉴스 분류)/weights_mission2.best.hdf5
# 16/16 [==============================] - 150s 9s/step - loss: 0.8058 - accuracy: 0.5198 - val_loss: 0.6893 - val_accuracy: 0.6429
# Epoch 2/300
# 16/16 [==============================] - ETA: 0s - loss: 0.7480 - accuracy: 0.5794
# Epoch 2: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 134s 8s/step - loss: 0.7480 - accuracy: 0.5794 - val_loss: 0.6846 - val_accuracy: 0.6429
# Epoch 3/300
# 16/16 [==============================] - ETA: 0s - loss: 0.7216 - accuracy: 0.5833
# Epoch 3: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 128s 8s/step - loss: 0.7216 - accuracy: 0.5833 - val_loss: 0.6802 - val_accuracy: 0.6429
# Epoch 4/300
# 16/16 [==============================] - ETA: 0s - loss: 0.7236 - accuracy: 0.6032
# Epoch 4: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 127s 8s/step - loss: 0.7236 - accuracy: 0.6032 - val_loss: 0.6762 - val_accuracy: 0.6429
# Epoch 5/300
# 16/16 [==============================] - ETA: 0s - loss: 0.6891 - accuracy: 0.6151
# Epoch 5: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 124s 8s/step - loss: 0.6891 - accuracy: 0.6151 - val_loss: 0.6723 - val_accuracy: 0.6429
# Epoch 6/300
# 16/16 [==============================] - ETA: 0s - loss: 0.6509 - accuracy: 0.6627
# Epoch 6: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 123s 8s/step - loss: 0.6509 - accuracy: 0.6627 - val_loss: 0.6686 - val_accuracy: 0.6429
# Epoch 7/300
# 16/16 [==============================] - ETA: 0s - loss: 0.6470 - accuracy: 0.6071
# Epoch 7: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 126s 8s/step - loss: 0.6470 - accuracy: 0.6071 - val_loss: 0.6646 - val_accuracy: 0.6429
# Epoch 8/300
# 16/16 [==============================] - ETA: 0s - loss: 0.6372 - accuracy: 0.6508
# Epoch 8: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 124s 8s/step - loss: 0.6372 - accuracy: 0.6508 - val_loss: 0.6610 - val_accuracy: 0.6429
# Epoch 9/300
# 16/16 [==============================] - ETA: 0s - loss: 0.5470 - accuracy: 0.7183
# Epoch 9: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 123s 8s/step - loss: 0.5470 - accuracy: 0.7183 - val_loss: 0.6575 - val_accuracy: 0.6429
# Epoch 10/300
# 16/16 [==============================] - ETA: 0s - loss: 0.5120 - accuracy: 0.7421
# Epoch 10: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 123s 8s/step - loss: 0.5120 - accuracy: 0.7421 - val_loss: 0.6543 - val_accuracy: 0.6429
# Epoch 11/300
# 16/16 [==============================] - ETA: 0s - loss: 0.5012 - accuracy: 0.7421
# Epoch 11: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 121s 8s/step - loss: 0.5012 - accuracy: 0.7421 - val_loss: 0.6515 - val_accuracy: 0.6429
# Epoch 12/300
# 16/16 [==============================] - ETA: 0s - loss: 0.4358 - accuracy: 0.8413
# Epoch 12: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 123s 8s/step - loss: 0.4358 - accuracy: 0.8413 - val_loss: 0.6488 - val_accuracy: 0.6429
# Epoch 13/300
# 16/16 [==============================] - ETA: 0s - loss: 0.4362 - accuracy: 0.8056
# Epoch 13: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 123s 8s/step - loss: 0.4362 - accuracy: 0.8056 - val_loss: 0.6454 - val_accuracy: 0.6429
# Epoch 14/300
# 16/16 [==============================] - ETA: 0s - loss: 0.4103 - accuracy: 0.8135
# Epoch 14: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 123s 8s/step - loss: 0.4103 - accuracy: 0.8135 - val_loss: 0.6435 - val_accuracy: 0.6429
# Epoch 15/300
# 16/16 [==============================] - ETA: 0s - loss: 0.3940 - accuracy: 0.8135
# Epoch 15: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 122s 8s/step - loss: 0.3940 - accuracy: 0.8135 - val_loss: 0.6416 - val_accuracy: 0.6429
# Epoch 16/300
# 16/16 [==============================] - ETA: 0s - loss: 0.3518 - accuracy: 0.8571
# Epoch 16: val_accuracy did not improve from 0.64286
# 16/16 [==============================] - 122s 8s/step - loss: 0.3518 - accuracy: 0.8571 - val_loss: 0.6412 - val_accuracy: 0.6429
# Epoch 16: early stopping

# %% [markdown]
# # Model validation
# #### * 만들어진 모델의 성능을 평가하기 위한 파트입니다.(accuracy로 평가)

# %%
concat_model.load_weights(best_weights_file)

## 위에서 분리해둔 test set에 대하여 모델 정확도 반환
print('\nAccuracy: {:.4f}'.format(concat_model.evaluate([x_test_content], y_test)[1])) 

y_vloss = history.history['val_loss'] # 학습 중 validation loss 저장
y_loss = history.history['loss'] # 학습 중 train loss 저장
x_len = np.arange(len(y_loss)) # 전체 epoch 길이 저장(현재 500)

plt.figure(figsize=(10,5))
plt.plot(x_len, y_vloss, marker='.', c='red', label="Validation-set Loss") # validation loss에 대한 그래프 출력
plt.plot(x_len, y_loss, marker='.', c='blue', label="Train-set Loss") # train loss에 대한 그래프 출력
plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
# Out:
# 3/3 [==============================] - 2s 496ms/step - loss: 0.6937 - accuracy: 0.5000
#
# Accuracy: 0.5000

# %%
 # Metrics for confusion matrix
y_pred = pd.DataFrame(concat_model.predict([x_test_content]),columns=['predict_label'])
y_pred[y_pred['predict_label']>=0.5] = 1
y_pred[y_pred['predict_label']<0.5] = 0
target_names = ['0','1']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        35
#            1       0.00      0.00      0.00        35
#
#     accuracy                           0.50        70
#    macro avg       0.25      0.50      0.33        70
# weighted avg       0.25      0.50      0.33        70
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# auroc
auroc_score = roc_auc_score(y_test, y_pred, average=None)
print("AUROC : ", round(auroc_score,2))

# roc curve graph
def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='blue', label='ROC')
    plt.plot([0, 1], [0, 1], color='red', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic Curve')
    plt.legend()
    plt.show()

prob = concat_model.predict([x_test_content])
fper, tper, thresholds = roc_curve(y_test, prob)
plot_roc_curve(fper, tper)
# Out:
# AUROC :  0.5
